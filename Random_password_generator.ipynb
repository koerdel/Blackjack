# %%
import random
string1 = ""


def auto_gen():
    auto = input("Do you want a auto generated password?")
    while True:
        if auto.lower().startswith("y"):
            return "yes"
        elif auto.lower().startswith("n"):
            return "no"
        else:
            auto = input("Do you want a auto generated password?")
        
def password_strength():
    strength = input("How strong do you want your password to be? Type Easy, Medium or Strong")
    while True:
        if strength.lower().startswith("e"):
            print(f"Your password strength is: {strength}")
            return strength

        elif strength.lower().startswith("m"):
            print(f"Your password strength is: {strength}")
            return strength

        elif strength.lower().startswith("s"):
            print(f"Your password strength is: {strength}")
            return strength  
        else:
            strength = input("How strong do you want your password to be? Type Easy, Medium or Strong")

def password_easy():
    return "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ"

def password_medium():
    return "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890"

def password_strong():
    return "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!#€%&/()=?`^¨*'_-:.;,><°§‘{}()[].,:;+-*/&|<>=~$'"


def password_length():
    length = input("How long do you want your password to be?")
    while True:
        try:
            int(length)
            length = int(length)
            if length > 20:
                print("Your password length it too long")
                length = input("Enter a number between 5-20") 
            elif length < 5:
                print("Your password length it too short")
                length = input("Enter a number between 5-20")
            else:
                print(f"Your password length is: {length}")
                return length
        except:
            length = input("Enter a number between 5-20")

               

def include_symbols():
    yes_no = ""
    string_of_symbols = "!#€%&/()=?`^¨*'_-:.;,><°§‘{}()[].,:;+-*/&|<>=~$'"
    while not yes_no.lower().startswith("y") or yes_no.lower().startswith("n"):
        yes_no = input("Do you want symbols in your generated password?")
        if yes_no.lower().startswith("y"):
            return string_of_symbols
        elif yes_no.lower().startswith("n"):
            return ""
        
def include_numbers():
    yes_no = ""
    string_of_numbers = "0123456789"
    while not yes_no.lower().startswith("y") or yes_no.lower().startswith("n"):
        yes_no = input("Do you want numbers in your generated password?")
        if yes_no.lower().startswith("y"):
            return string_of_numbers
        elif yes_no.lower().startswith("n"):
            return ""
        
def include_lowercase():
    yes_no = ""
    string_of_lowercase = "abcdefghijklmnopqrstuvwxyz"
    while not yes_no.lower().startswith("y") or yes_no.lower().startswith("n"):
        yes_no = input("Do you want lowercase letters in your generated password?")
        if yes_no.lower().startswith("y"):
            return string_of_lowercase
        elif yes_no.lower().startswith("n"):
            return ""
        
def include_uppercase():
    yes_no = ""
    string_of_uppercase = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    while not yes_no.lower().startswith("y") or yes_no.lower().startswith("n"):
        yes_no = input("Do you want uppercase letters in your generated password?")
        if yes_no.lower().startswith("y"):
            return string_of_uppercase
        elif yes_no.lower().startswith("n"):
            return ""
        
def password_gen(string1):
    password = ""
    for i in range(number):
        random_char = random.choice(string1)
        password += random_char
    return password
        

auto_gen2 = auto_gen()

if auto_gen2 == "yes":
    strength = password_strength()
    if strength.lower().startswith("e"):
        number = 5
        password1 = password_gen(password_easy())
        print(f"Your password is: {password1}")
        
    elif strength.lower().startswith("m"):
        number = 10
        password1 = password_gen(password_medium())
        print(f"Your password is: {password1}")    

    elif strength.lower().startswith("s"):
        number = 15
        password1 = password_gen(password_strong())
        print(f"Your password is: {password1}")    
else:
    number = password_length()
    string1 += include_symbols() + include_numbers() + include_lowercase() + include_uppercase()
    password1 = password_gen(string1)
    print(f"Your password is: {password1}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-39a28414dbe4> in <module>
#     108
#     109
# --> 110 auto_gen2 = auto_gen()
#     111
#     112 if auto_gen2 == "yes":
#
# <ipython-input-61-39a28414dbe4> in auto_gen()
#       4
#       5 def auto_gen():
# ----> 6     auto = input("Do you want a auto generated password?")
#       7     while True:
#       8         if auto.lower().startswith("y"):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ...

# %%
import random
string1 = ""
number = 0
